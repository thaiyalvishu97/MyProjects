# %% [markdown]
# <a href="https://colab.research.google.com/github/thaiyalvishu97/MyProjects/blob/main/Project_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project 9 - Rice Classification

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC

# %%
df = pd.read_csv('riceClassification.csv')

# %%
df.isnull().sum()
# Out:
# id                 0
# Area               0
# MajorAxisLength    0
# MinorAxisLength    0
# Eccentricity       0
# ConvexArea         0
# EquivDiameter      0
# Extent             0
# Perimeter          0
# Roundness          0
# AspectRation       0
# Class              0
# dtype: int64

# %%
df.tail(n=10)
# Out:
#           id  Area  MajorAxisLength  MinorAxisLength  Eccentricity  \
# 18175  18176  9101       183.211434        65.025256      0.934897
# 18176  18177  7595       166.372864        59.045507      0.934905
# 18177  18178  5865       146.173653        51.619196      0.935572
# 18178  18179  6165       149.401504        52.686933      0.935754
# 18179  18180  5757       146.505031        50.650032      0.938337
# 18180  18181  5853       148.624571        51.029281      0.939210
# 18181  18182  7585       169.593996        58.141659      0.939398
# 18182  18183  6365       154.777085        52.908085      0.939760
# 18183  18184  5960       151.397924        51.474600      0.940427
# 18184  18185  6134       153.081981        51.590606      0.941500
#
#        ConvexArea  EquivDiameter    Extent  Perimeter  Roundness  \
# 18175        9431     107.646426  0.474505    414.047   0.667113
# 18176        7734      98.337451  0.482406    371.322   0.692207
# ...

# %%
X = df.drop(columns=['id','Class'],axis=1)
Y = df['Class']
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,random_state=42,test_size=0.2)

# %%
model = SVC(kernel="linear")
model.fit(X_train,Y_train)
Y_predicted = model.predict(X_test)

# %%
print('Accuracy:',accuracy_score(Y_predicted,Y_test))
# Out:
# Accuracy: 0.9895518284300248

# %%
new = [[9101,183.211434,65.025256,0.934897,9431,107.646426,0.474505,414.047,0.667113,2.817543]]
result = model.predict(new)
print('''
1 - Jasmine,
0 - Gonen
''')
print("Rice class for the given data :",result)
# Out:
# 1 - Jasmine,
# 0 - Gonen
#
# Rice class for the given data : [0]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
